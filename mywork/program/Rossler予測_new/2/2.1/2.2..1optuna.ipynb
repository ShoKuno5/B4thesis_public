# %%
# %% [markdown]
# # レスラー方程式(外力のある状態)
# 
# レスラー方程式の外力のある場合に関して，$sin$波に位相のシフトがある場合を考える．

# %%
#必要なパッケージのインポート

import numpy as np

import matplotlib
import matplotlib.pyplot as plt

import reservoirpy as rpy

from scipy.integrate import solve_ivp
import pandas as pd
from reservoirpy.observables import nrmse, rsquare

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


rpy.verbosity(0)

from reservoirpy.nodes import Reservoir, Ridge
from reservoirpy.datasets import mackey_glass

# just a little tweak to center the plots, nothing to worry about
from IPython.core.display import HTML
HTML("""
<style>
.img-center {
    display: block;
    margin-left: auto;
    margin-right: auto;
    }
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
    }
</style>
""")

rpy.set_seed(42)




# %%
filename_with_force = 'rossler_data_with_shifted_force2.1.1.csv'

# CSVファイルを読み込む
data_loaded_with_force = pd.read_csv(filename_with_force)

# CSVから値を抽出してNumpy配列に格納
X = data_loaded_with_force[['x', 'y', 'P_shifted']].values

from reservoirpy.datasets import to_forecasting

train_len = 10000
test_len = 10000

x, y = to_forecasting(X, forecast=1)
X_train, y_train = x[:train_len], y[:train_len]
X_test, y_test = x[train_len:train_len+test_len], y[train_len:train_len+test_len]

dataset = ((X_train, y_train), (X_test, y_test))

# This step may vary depending on what you put inside 'dataset'
train_data, validation_data = dataset
X_train, y_train = train_data
X_val, y_val = validation_data

# %%
import optuna

# %%
# Optunaの目的関数
def objective(trial):
    # パラメータの提案
    N_value = 5000  # Nの値は固定
    sr = trial.suggest_float('sr', 1e-2, 10, log = True)
    lr = trial.suggest_float('lr', 1e-3, 1, log = True)
    iss = trial.suggest_float('iss', 0, 1)
    ridge = trial.suggest_float('ridge', 1e-9, 1e-2, log = True)
    
    losses = []; r2s = [];
    for n in range(3):  # 例としてインスタンスごとに3回試行
        # モデルの構築
        reservoir = Reservoir(N_value, sr=sr, lr=lr, input_scaling=iss, seed=n)
        readout = Ridge(ridge=ridge)
        model = reservoir >> readout

        # モデルの訓練とテスト
        # Train your model and test your model.
        prediction = model.fit(X_train, y_train) \
                           .run(X_test)
        
        loss = nrmse(y_test, prediction, norm_value=np.ptp(X_train))
        r2 = rsquare(y_test, prediction)

        # 評価指標の計算
        loss = nrmse(y_test, prediction, norm_value=np.ptp(X_train))
        r2 = rsquare(y_test, prediction)
        losses.append(loss)
        r2s.append(r2)
        
         # トライアルの進捗を報告
        trial.report(np.mean(losses), n)

        # プルーニングのチェック
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

    return np.mean(losses)

# %%
# Optunaのプルーナーを定義
pruner = optuna.pruners.MedianPruner()

# Optunaのスタディを作成し、プルーナーを指定
study = optuna.create_study(direction='minimize', pruner=pruner)
study.optimize(objective, n_trials=300)
# Out:
# [I 2023-11-11 19:20:00,074] A new study created in memory with name: no-name-263488af-c825-4606-bb56-30ffb673c2a6
# [W 2023-11-11 19:21:13,648] Trial 0 failed with parameters: {'sr': 2.095696434533729, 'lr': 0.0025782978281261226, 'iss': 0.5354247388132112, 'ridge': 0.0016083602491766841} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/Users/manqueenmannequin/miniforge3/envs/python38gen2/lib/python3.8/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "/var/folders/y4/6674dz116775fry8d67k82wm0000gn/T/ipykernel_15451/3564247350.py", line 19, in objective
#     prediction = model.fit(X_train, y_train) \
#   File "/Users/manqueenmannequin/miniforge3/envs/python38gen2/lib/python3.8/site-packages/reservoirpy/model.py", line 917, in run
#     states_seq = self._run(
#   File "/Users/manqueenmannequin/miniforge3/envs/python38gen2/lib/python3.8/site-packages/reservoirpy/model.py", line 446, in _run
#     state = submodel._call(x, return_states=return_states)
#   File "/Users/manqueenmannequin/miniforge3/envs/python38gen2/lib/python3.8/site-packages/reservoirpy/model.py", line 398, in _call
#     self._forward(submodel, x)
#   File "/Users/manqueenmannequin/miniforge3/envs/python38gen2/lib/python3.8/site-packages/reservoirpy/model.py", line 220, in forward
#     _base.call(node, data[node].x)
#   File "/Users/manqueenmannequin/miniforge3/envs/python38gen2/lib/python3.8/site-packages/reservoirpy/_base.py", line 530, in call
#     state = node._forward(node, x)
#   File "/Users/manqueenmannequin/miniforge3/envs/python38gen2/lib/python3.8/site-packages/reservoirpy/nodes/reservoirs/base.py", line 59, in forward_internal
#     + np.multiply(lr, f(reservoir_kernel(reservoir, u, r)).T).T
#   File "/Users/manqueenmannequin/miniforge3/envs/python38gen2/lib/python3.8/site-packages/reservoirpy/nodes/reservoirs/base.py", line 23, in reservoir_kernel
#     pre_s = W @ r + Win @ (u + noise_gen(dist=dist, shape=u.shape, gain=g_in)) + bias
#   File "/Users/manqueenmannequin/miniforge3/envs/python38gen2/lib/python3.8/site-packages/scipy/sparse/_base.py", line 630, in __matmul__
#     return self._mul_dispatch(other)
#   File "/Users/manqueenmannequin/miniforge3/envs/python38gen2/lib/python3.8/site-packages/scipy/sparse/_base.py", line 530, in _mul_dispatch
#     return self._mul_vector(other.ravel()).reshape(M, 1)
#   File "/Users/manqueenmannequin/miniforge3/envs/python38gen2/lib/python3.8/site-packages/scipy/sparse/_compressed.py", line 489, in _mul_vector
#     fn(M, N, self.indptr, self.indices, self.data, other, result)
# KeyboardInterrupt
# [W 2023-11-11 19:21:13,650] Trial 0 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/manqueenmannequin/mygit/B4thesis_public/mywork/program/Rossler予測_new/2/2.1/2.2..1optuna.ipynb セル 4 line 6
#       <a href='vscode-notebook-cell:/Users/manqueenmannequin/mygit/B4thesis_public/mywork/program/Rossler%E4%BA%88%E6%B8%AC_new/2/2.1/2.2..1optuna.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> # Optunaのスタディを作成し、プルーナーを指定
#       <a href='vscode-notebook-cell:/Users/manqueenmannequin/mygit/B4thesis_public/mywork/program/Rossler%E4%BA%88%E6%B8%AC_new/2/2.1/2.2..1optuna.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> study = optuna.create_study(direction='minimize', pruner=pruner)
# ----> <a href='vscode-notebook-cell:/Users/manqueenmannequin/mygit/B4thesis_public/mywork/program/Rossler%E4%BA%88%E6%B8%AC_new/2/2.1/2.2..1optuna.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> study.optimize(objective, n_trials=300)
#
# File ~/miniforge3/envs/python38gen2/lib/python3.8/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File ~/miniforge3/envs/python38gen2/lib/python3.8/site-packages/optuna/study/_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~/miniforge3/envs/python38gen2/lib/python3.8/site-packages/optuna/study/_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~/miniforge3/envs/python38gen2/lib/python3.8/site-packages/optuna/study/_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~/miniforge3/envs/python38gen2/lib/python3.8/site-packages/optuna/study/_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# /Users/manqueenmannequin/mygit/B4thesis_public/mywork/program/Rossler予測_new/2/2.1/2.2..1optuna.ipynb セル 4 line 1
#      <a href='vscode-notebook-cell:/Users/manqueenmannequin/mygit/B4thesis_public/mywork/program/Rossler%E4%BA%88%E6%B8%AC_new/2/2.1/2.2..1optuna.ipynb#W3sZmlsZQ%3D%3D?line=14'>15</a> model = reservoir >> readout
#      <a href='vscode-notebook-cell:/Users/manqueenmannequin/mygit/B4thesis_public/mywork/program/Rossler%E4%BA%88%E6%B8%AC_new/2/2.1/2.2..1optuna.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a> # モデルの訓練とテスト
#      <a href='vscode-notebook-cell:/Users/manqueenmannequin/mygit/B4thesis_public/mywork/program/Rossler%E4%BA%88%E6%B8%AC_new/2/2.1/2.2..1optuna.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a> # Train your model and test your model.
# ---> <a href='vscode-notebook-cell:/Users/manqueenmannequin/mygit/B4thesis_public/mywork/program/Rossler%E4%BA%88%E6%B8%AC_new/2/2.1/2.2..1optuna.ipynb#W3sZmlsZQ%3D%3D?line=18'>19</a> prediction = model.fit(X_train, y_train) \
#      <a href='vscode-notebook-cell:/Users/manqueenmannequin/mygit/B4thesis_public/mywork/program/Rossler%E4%BA%88%E6%B8%AC_new/2/2.1/2.2..1optuna.ipynb#W3sZmlsZQ%3D%3D?line=19'>20</a>                    .run(X_test)
#      <a href='vscode-notebook-cell:/Users/manqueenmannequin/mygit/B4thesis_public/mywork/program/Rossler%E4%BA%88%E6%B8%AC_new/2/2.1/2.2..1optuna.ipynb#W3sZmlsZQ%3D%3D?line=21'>22</a> loss = nrmse(y_test, prediction, norm_value=np.ptp(X_train))
#      <a href='vscode-notebook-cell:/Users/manqueenmannequin/mygit/B4thesis_public/mywork/program/Rossler%E4%BA%88%E6%B8%AC_new/2/2.1/2.2..1optuna.ipynb#W3sZmlsZQ%3D%3D?line=22'>23</a> r2 = rsquare(y_test, prediction)
#
# File ~/miniforge3/envs/python38gen2/lib/python3.8/site-packages/reservoirpy/model.py:917, in Model.run(self, X, forced_feedbacks, from_state, stateful, reset, shift_fb, return_states)
#     915 for X_seq, fb_seq in zip(X_, forced_feedbacks_):
#     916     with self.with_state(reset=reset, stateful=stateful):
# --> 917         states_seq = self._run(
#     918             X_seq,
#     919             fb_seq,
#     920             from_state=from_state,
#     921             stateful=stateful,
#     922             shift_fb=shift_fb,
#     923             return_states=return_states,
#     924         )
#     926         states.append(states_seq)
#     928 return fold_mapping(self, states, return_states)
#
# File ~/miniforge3/envs/python38gen2/lib/python3.8/site-packages/reservoirpy/model.py:446, in Model._run(self, X, feedback, from_state, stateful, shift_fb, return_states, submodel)
#     443 for i, (x, forced_fb, _) in enumerate(seq):
#     445     with self.with_feedback(forced_fb):
# --> 446         state = submodel._call(x, return_states=return_states)
#     448     if is_mapping(state):
#     449         for name, value in state.items():
#
# File ~/miniforge3/envs/python38gen2/lib/python3.8/site-packages/reservoirpy/model.py:398, in Model._call(self, x, return_states, submodel, *args, **kwargs)
#     395 if submodel is None:
#     396     submodel = self
# --> 398 self._forward(submodel, x)
#     400 state = {}
#     401 if return_states == "all":
#
# File ~/miniforge3/envs/python38gen2/lib/python3.8/site-packages/reservoirpy/model.py:220, in forward(model, x)
#     217 data = model.data_dispatcher.load(x)
#     219 for node in model.nodes:
# --> 220     _base.call(node, data[node].x)
#     222 return [out_node.state() for out_node in model.output_nodes]
#
# File ~/miniforge3/envs/python38gen2/lib/python3.8/site-packages/reservoirpy/_base.py:530, in call(node, x, from_state, stateful, reset)
#     528 """One-step call, without input check."""
#     529 with node.with_state(from_state, stateful=stateful, reset=reset):
# --> 530     state = node._forward(node, x)
#     531     node._state = state.astype(node.dtype)
#     532     node._flag_feedback()
#
# File ~/miniforge3/envs/python38gen2/lib/python3.8/site-packages/reservoirpy/nodes/reservoirs/base.py:59, in forward_internal(reservoir, x)
#      54 u = x.reshape(-1, 1)
#      55 r = reservoir.state().T
#      57 s_next = (
#      58     np.multiply((1 - lr), r.T).T
# ---> 59     + np.multiply(lr, f(reservoir_kernel(reservoir, u, r)).T).T
#      60     + noise_gen(dist=dist, shape=r.shape, gain=g_rc)
#      61 )
#      63 return s_next.T
#
# File ~/miniforge3/envs/python38gen2/lib/python3.8/site-packages/reservoirpy/nodes/reservoirs/base.py:23, in reservoir_kernel(reservoir, u, r)
#      20 dist = reservoir.noise_type
#      21 noise_gen = reservoir.noise_generator
# ---> 23 pre_s = W @ r + Win @ (u + noise_gen(dist=dist, shape=u.shape, gain=g_in)) + bias
#      25 if reservoir.has_feedback:
#      26     Wfb = reservoir.Wfb
#
# File ~/miniforge3/envs/python38gen2/lib/python3.8/site-packages/scipy/sparse/_base.py:630, in spmatrix.__matmul__(self, other)
#     627 if isscalarlike(other):
#     628     raise ValueError("Scalar operands are not allowed, "
#     629                      "use '*' instead")
# --> 630 return self._mul_dispatch(other)
#
# File ~/miniforge3/envs/python38gen2/lib/python3.8/site-packages/scipy/sparse/_base.py:530, in spmatrix._mul_dispatch(self, other)
#     528     return self._mul_vector(other)
#     529 elif other.shape == (N, 1):
# --> 530     return self._mul_vector(other.ravel()).reshape(M, 1)
#     531 elif other.ndim == 2 and other.shape[0] == N:
#     532     return self._mul_multivector(other)
#
# File ~/miniforge3/envs/python38gen2/lib/python3.8/site-packages/scipy/sparse/_compressed.py:489, in _cs_matrix._mul_vector(self, other)
#     487 # csr_matvec or csc_matvec
#     488 fn = getattr(_sparsetools, self.format + '_matvec')
# --> 489 fn(M, N, self.indptr, self.indices, self.data, other, result)
#     491 return result
#
# KeyboardInterrupt:

# %%
# 最適なパラメータの取得と保存
best_params = study.best_param
